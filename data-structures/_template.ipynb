# %% [markdown]
# > **Template.** Copy this file to `data-structures/<topic>.ipynb`, fill it in, then delete this note.
# >
# > Keep the house pattern: **concept → how CPython implements it → a demo that *proves* the claim → when-to-use → cheat-sheet.** Every nontrivial claim should have a runnable cell that demonstrates it.

# %% [markdown]
# # <Topic>
#
# One-paragraph intro: what this structure is, and the behind-the-scenes angle this notebook takes.
#
# **Contents**
#
# 1. What it is
# 2. CPython internals
# 3. Key behavior / gotcha
# 4. Variants & alternatives
# 5. When to use what
# 6. Complexity cheat-sheet

# %% [markdown]
# ## 1. What it is
#
# The plain-language model: what it stores, the core operations, and the one or two properties that define it.

# %% [markdown]
# ## 2. CPython internals
#
# How it's actually represented under the hood — the struct, the memory layout, the growth/allocation strategy, the optimizations. This is the heart of the notebook.

# %%
# demo that PROVES an internals claim (sys.getsizeof, id(), timing, ...)

# %% [markdown]
# ## 3. Key behavior / gotcha
#
# A consequence that bites people in practice — a complexity cliff, a mutation surprise, identity vs equality, etc.

# %%
# demo

# %% [markdown]
# ## 4. Variants & alternatives
#
# Related types / stdlib options and how they trade off (mutability, memory, performance).

# %%
# demo

# %% [markdown]
# ## 5. When to use what
#
# | You need... | Reach for | Why |
# |---|---|---|
# | ... | ... | ... |

# %% [markdown]
# ## 6. Complexity cheat-sheet
#
# | Operation | A | B | C |
# |---|:---:|:---:|:---:|
# | Index access |  |  |  |
# | Append |  |  |  |
# | Insert front |  |  |  |
# | Search |  |  |  |
# | Memory / element |  |  |  |
